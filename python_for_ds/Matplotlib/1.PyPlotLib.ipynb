# %% [markdown]
# ### Pyplot Tutorial:

# %% [markdown]
# **matplotlib.pyplot** is a collection of command style functions that make matplotlib work like MATLAB.
#
# Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
# installing matplotlib
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/e9/69/f5e05f578585ed9935247be3788b374f90701296a70c8871bcd6d21edb00/matplotlib-3.0.3-cp36-cp36m-manylinux1_x86_64.whl (13.0MB)
#     100% |████████████████████████████████| 13.0MB 376kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /srv/conda/lib/python3.6/site-packages (from matplotlib) (2.7.5)
# Collecting numpy>=1.10.0 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/35/d5/4f8410ac303e690144f0a0603c4b8fd3b986feb2749c435f7cdbb288f17e/numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#     100% |████████████████████████████████| 17.3MB 239kB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/69/a7/88719d132b18300b4369fbffa741841cfd36d1e637e1990f27929945b538/kiwisolver-1.0.1-cp36-cp36m-manylinux1_x86_64.whl (949kB)
#     100% |████████████████████████████████| 952kB 9.1MB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/de/0a/001be530836743d8be6c2d85069f46fecf84ac6c18c7f5fb8125ee11d854/pyparsing-2.3.1-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 71kB 27.3MB/s ta 0:00:01
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib) (40.7.1)
# Installing collected packages: numpy, kiwisolver, cycler, pyparsing, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.0.1 matplotlib-3.0.3 numpy-1.16.2 pyparsing-2.3.1

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2,4,6,4])
plt.ylabel("Numbers")
plt.xlabel("Indices")
plt.title("Myplot")
plt.show()

# %% [markdown]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3].

# %% [markdown]
# #### plot x versus y

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.ylabel("squares")
plt.xlabel("numbers")
plt.grid() # grid on

plt.show()

# %% [markdown]
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot.

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro') # 'ro' - red circle
plt.grid()
plt.show()

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally.

# %%
# to install numpy
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: numpy in /srv/conda/lib/python3.6/site-packages (1.16.2)

# %%
import numpy as np

# %%
t = np.arange(0,5,0.2)

# blue dashes, red squares and green triangle

plt.plot(t,t**2,'b--',label='^2')
plt.plot(t,t**2.2,'rs',label="^2.2")
plt.plot(t,t**2.5,'g^',label = '^2.5')

plt.grid()
plt.legend() # add legend based on line labels
plt.show()

# %% [markdown]
# ### Controlling line properties

# %% [markdown]
# #### use keyword args

# %%
x = [1,2,3,4]
y = [1,4,9,16]

plt.plot(x,y,linewidth = 5.0)
plt.show()

# %% [markdown]
# #### use the setp()

# %%
x1 = [1,2,3,4]
y1 = [1,4,9,16]
x2 = [1,2,3,4]
y2 = [2,4,6,8]
x3 = [1,2,3,4]
y3 = [12,14,16,18]
x4 = [1,2,3,4]
y4 = [2,6,12,20]

lines = plt.plot(x1,y1,x2,y2,x3,y3,'mo',label="sample") # this will set the default label to all the present lines as sample
plt.plot(x4,y4,'g^',label="sequence")

# use keyword args

plt.setp(lines[0],color='r',linewidth = 2.0)

# or matlab style using string value pair

plt.setp(lines[1],'color','g','linewidth','2.0')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### working with multiple figures and axes

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
# The subplot() command specifies numrows, numcols, 
# fignum where fignum ranges from 1 to numrows*numcols.
# 211 - 2 subplots, first subplot in the first figure
plt.subplot(211)
plt.grid()
plt.plot(t1, f(t1), 'b-')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
plt.figure(1)         # the first figure
plt.subplot(211)      # the first subplot in first figure
plt.plot([1,2,3])
plt.subplot(212)
plt.plot([4,5,6])

plt.figure(2)
plt.plot([4,5,6])

plt.figure(1)
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.show()

# %%
# Making four plots
d = np.array([1,2,3,4,5])

plt.figure(1)

# figure 1, making 2 rows and 2 columns
# subplot 2,2 stands for rows and columns here

plt.subplot(221)
plt.plot(d,d**2,'r',linewidth='2.0')

plt.subplot(222)
plt.plot(d,d**2,'g',linewidth='2.0')

plt.subplot(223)
plt.plot(d,d**2,'m',linewidth='2.0')

plt.subplot(224)
plt.plot(d,d**2,'b',linewidth='2.0')

plt.show()

# %%
data = np.loadtxt("populations.txt")
print(data)
# Out:
# [[ 1900. 30000.  4000. 48300.]
#  [ 1901. 47200.  6100. 48200.]
#  [ 1902. 70200.  9800. 41500.]
#  [ 1903. 77400. 35200. 38200.]
#  [ 1904. 36300. 59400. 40600.]
#  [ 1905. 20600. 41700. 39800.]
#  [ 1906. 18100. 19000. 38600.]
#  [ 1907. 21400. 13000. 42300.]
#  [ 1908. 22000.  8300. 44500.]
#  [ 1909. 25400.  9100. 42100.]
#  [ 1910. 27100.  7400. 46000.]
#  [ 1911. 40300.  8000. 46800.]
#  [ 1912. 57000. 12300. 43800.]
#  [ 1913. 76600. 19500. 40900.]
#  [ 1914. 52300. 45700. 39400.]
#  [ 1915. 19500. 51100. 39000.]
#  [ 1916. 11200. 29700. 36700.]
#  [ 1917.  7600. 15800. 41800.]
#  [ 1918. 14600.  9700. 43300.]
#  [ 1919. 16200. 10100. 41300.]
#  [ 1920. 24700.  8600. 47300.]]

# %%
year,hare,lynx,carrot = data.T
print(year)
print("*********")
print(hare)
print("*********")
print(lynx)
print("*********")
print(carrot)
print("*********")
# Out:
# [1900. 1901. 1902. 1903. 1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911.
#  1912. 1913. 1914. 1915. 1916. 1917. 1918. 1919. 1920.]
# *********
# [30000. 47200. 70200. 77400. 36300. 20600. 18100. 21400. 22000. 25400.
#  27100. 40300. 57000. 76600. 52300. 19500. 11200.  7600. 14600. 16200.
#  24700.]
# *********
# [ 4000.  6100.  9800. 35200. 59400. 41700. 19000. 13000.  8300.  9100.
#   7400.  8000. 12300. 19500. 45700. 51100. 29700. 15800.  9700. 10100.
#   8600.]
# *********
# [48300. 48200. 41500. 38200. 40600. 39800. 38600. 42300. 44500. 42100.
#  46000. 46800. 43800. 40900. 39400. 39000. 36700. 41800. 43300. 41300.
#  47300.]
# *********

# %%
plt.figure(1)
plt.subplot(1,2,1)

lines = plt.plot(year,hare,year,lynx,year,carrot)

plt.setp(lines[0], color='r',linewidth = '2.0')
plt.setp(lines[1], color='b',linewidth = '2.0')
plt.setp(lines[2], color='g',linewidth = '2.0')

# other graph for the same data
plt.subplot(1,2,2)

plt.plot(year,hare,'ro',label="hare")
plt.plot(year,lynx,'g^',label="lynx")
plt.plot(year,carrot,'ms',label="carrot")

plt.grid()
plt.legend()
plt.show()
